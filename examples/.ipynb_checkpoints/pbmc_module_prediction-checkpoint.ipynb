# %%
from pathlib import Path

import anndata
import scanpy as sc
import pandas as pd
import seaborn as sns

import pollock
from pollock.models.model import PollockDataset, PollockModel, load_from_directory

# %% [markdown]
# specify which module to use for cell type predictions

# %%
module_filepath = 'modules/pbmc'

# %% [markdown]
# download adata object here
#
# it is also the same anndata object create here

# %%
adata = sc.read_h5ad('data/pbmc.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# create a new anndata object where raw counts are stored in .X

# %%
prediction_adata = anndata.AnnData(X=adata.layers['raw_counts'],
                                  obs=adata.obs,
                                  var=adata.var)

# %% [markdown]
# create PollockDataset and load in module

# %%
loaded_pds, loaded_pm = load_from_directory(prediction_adata, module_filepath)
# Out:
# 2020-06-09 10:57:35,518 normalizing counts for prediction
# 2020-06-09 10:57:35,519 filtering for genes in training set
# 2020-06-09 10:57:35,520 0 genes in training set are missing from prediction set
# /Users/erikstorrs/miniconda3/envs/pollock/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:339: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# 2020-06-09 10:57:35,546 scaling data

# %% [markdown]
# predict cell types
#
# returns cell type labels, probability for the given cell type labels, and the probabilities of all cell types

# %%
labels, probs, cell_type_probs = loaded_pm.predict_pollock_dataset(loaded_pds, labels=True, )

df = pd.DataFrame.from_dict({
    'predicted_cell_type': labels,
    'cell_type_probability': probs,
})
df.index = prediction_adata.obs.index
df = pd.concat((df, pd.DataFrame(data=cell_type_probs, index=prediction_adata.obs.index,
                            columns=[f'probability_{c}' for c in loaded_pds.cell_types])), axis=1)
df
# Out:
#                  predicted_cell_type  cell_type_probability  probability_B  \
# AAACATACAACCAC-1               CD4 T                   0.90           0.01
# AAACATTGAGCTAC-1                   B                   0.77           0.77
# AAACATTGATCAGC-1               CD4 T                   0.73           0.06
# AAACCGTGCTTCCG-1      CD14 Monocytes                   0.53           0.00
# AAACCGTGTATGCG-1               CD8 T                   0.58           0.00
# ...                              ...                    ...            ...
# TTTCGAACTCTCAT-1      CD14 Monocytes                   0.60           0.00
# TTTCTACTGAGGCA-1                   B                   0.91           0.91
# TTTCTACTTCCTCG-1                   B                   1.00           1.00
# TTTGCATGAGAGGC-1                   B                   1.00           1.00
# TTTGCATGCCTCAC-1               CD4 T                   0.98           0.00
#
#                   probability_CD14 Monocytes  probability_CD4 T  \
# AAACATACAACCAC-1                        0.00               0.90
# AAACATTGAGCTAC-1                        0.03               0.02
# AAACATTGATCAGC-1                        0.01               0.73
# AAACCGTGCTTCCG-1                        0.53               0.00
# AAACCGTGTATGCG-1                        0.00               0.01
# ...                                      ...                ...
# TTTCGAACTCTCAT-1                        0.60               0.00
# TTTCTACTGAGGCA-1                        0.00               0.04
# TTTCTACTTCCTCG-1                        0.00               0.00
# TTTGCATGAGAGGC-1                        0.00               0.00
# TTTGCATGCCTCAC-1                        0.01               0.98
#
#                   probability_CD8 T  probability_Dendritic  \
# AAACATACAACCAC-1               0.09                   0.00
# AAACATTGAGCTAC-1               0.04                   0.08
# AAACATTGATCAGC-1               0.13                   0.02
# AAACCGTGCTTCCG-1               0.00                   0.02
# AAACCGTGTATGCG-1               0.58                   0.01
# ...                             ...                    ...
# TTTCGAACTCTCAT-1               0.00                   0.38
# TTTCTACTGAGGCA-1               0.00                   0.02
# TTTCTACTTCCTCG-1               0.00                   0.00
# TTTGCATGAGAGGC-1               0.00                   0.00
# TTTGCATGCCTCAC-1               0.01                   0.00
#
#                   probability_FCGR3A Monocytes  probability_Megakaryocytes  \
# AAACATACAACCAC-1                          0.00                        0.00
# AAACATTGAGCTAC-1                          0.04                        0.02
# AAACATTGATCAGC-1                          0.02                        0.01
# AAACCGTGCTTCCG-1                          0.45                        0.00
# AAACCGTGTATGCG-1                          0.04                        0.00
# ...                                        ...                         ...
# TTTCGAACTCTCAT-1                          0.02                        0.00
# TTTCTACTGAGGCA-1                          0.02                        0.01
# TTTCTACTTCCTCG-1                          0.00                        0.00
# TTTGCATGAGAGGC-1                          0.00                        0.00
# TTTGCATGCCTCAC-1                          0.00                        0.00
#
#                   probability_NK
# AAACATACAACCAC-1            0.00
# AAACATTGAGCTAC-1            0.00
# AAACATTGATCAGC-1            0.02
# AAACCGTGCTTCCG-1            0.00
# AAACCGTGTATGCG-1            0.36
# ...                          ...
# TTTCGAACTCTCAT-1            0.00
# TTTCTACTGAGGCA-1            0.00
# TTTCTACTTCCTCG-1            0.00
# TTTGCATGAGAGGC-1            0.00
# TTTGCATGCCTCAC-1            0.00
#
# [2638 rows x 10 columns]

# %%
adata.obs = pd.merge(adata.obs, df, left_index=True, right_index=True)
adata.obs
# Out:
#                   n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACATACAACCAC-1      781                779        2419.0             73.0
# AAACATTGAGCTAC-1     1352               1352        4903.0            186.0
# AAACATTGATCAGC-1     1131               1129        3147.0             28.0
# AAACCGTGCTTCCG-1      960                960        2639.0             46.0
# AAACCGTGTATGCG-1      522                521         980.0             12.0
# ...                   ...                ...           ...              ...
# TTTCGAACTCTCAT-1     1155               1153        3459.0             73.0
# TTTCTACTGAGGCA-1     1227               1224        3443.0             32.0
# TTTCTACTTCCTCG-1      622                622        1684.0             37.0
# TTTGCATGAGAGGC-1      454                452        1022.0             21.0
# TTTGCATGCCTCAC-1      724                723        1984.0             16.0
#
#                   pct_counts_mt          leiden predicted_cell_type  \
# AAACATACAACCAC-1       3.017776           CD4 T               CD4 T
# AAACATTGAGCTAC-1       3.793596               B                   B
# AAACATTGATCAGC-1       0.889736           CD4 T               CD4 T
# AAACCGTGCTTCCG-1       1.743085  CD14 Monocytes      CD14 Monocytes
# AAACCGTGTATGCG-1       1.224490              NK               CD8 T
# ...                         ...             ...                 ...
# TTTCGAACTCTCAT-1       2.110436  CD14 Monocytes      CD14 Monocytes
# TTTCTACTGAGGCA-1       0.929422               B                   B
# TTTCTACTTCCTCG-1       2.197150               B                   B
# TTTGCATGAGAGGC-1       2.054795               B                   B
# TTTGCATGCCTCAC-1       0.806452           CD4 T               CD4 T
#
#                   cell_type_probability  probability_B  \
# AAACATACAACCAC-1                   0.90           0.01
# AAACATTGAGCTAC-1                   0.77           0.77
# AAACATTGATCAGC-1                   0.73           0.06
# AAACCGTGCTTCCG-1                   0.53           0.00
# AAACCGTGTATGCG-1                   0.58           0.00
# ...                                 ...            ...
# TTTCGAACTCTCAT-1                   0.60           0.00
# TTTCTACTGAGGCA-1                   0.91           0.91
# TTTCTACTTCCTCG-1                   1.00           1.00
# TTTGCATGAGAGGC-1                   1.00           1.00
# TTTGCATGCCTCAC-1                   0.98           0.00
#
#                   probability_CD14 Monocytes  probability_CD4 T  \
# AAACATACAACCAC-1                        0.00               0.90
# AAACATTGAGCTAC-1                        0.03               0.02
# AAACATTGATCAGC-1                        0.01               0.73
# AAACCGTGCTTCCG-1                        0.53               0.00
# AAACCGTGTATGCG-1                        0.00               0.01
# ...                                      ...                ...
# TTTCGAACTCTCAT-1                        0.60               0.00
# TTTCTACTGAGGCA-1                        0.00               0.04
# TTTCTACTTCCTCG-1                        0.00               0.00
# TTTGCATGAGAGGC-1                        0.00               0.00
# TTTGCATGCCTCAC-1                        0.01               0.98
#
#                   probability_CD8 T  probability_Dendritic  \
# AAACATACAACCAC-1               0.09                   0.00
# AAACATTGAGCTAC-1               0.04                   0.08
# AAACATTGATCAGC-1               0.13                   0.02
# AAACCGTGCTTCCG-1               0.00                   0.02
# AAACCGTGTATGCG-1               0.58                   0.01
# ...                             ...                    ...
# TTTCGAACTCTCAT-1               0.00                   0.38
# TTTCTACTGAGGCA-1               0.00                   0.02
# TTTCTACTTCCTCG-1               0.00                   0.00
# TTTGCATGAGAGGC-1               0.00                   0.00
# TTTGCATGCCTCAC-1               0.01                   0.00
#
#                   probability_FCGR3A Monocytes  probability_Megakaryocytes  \
# AAACATACAACCAC-1                          0.00                        0.00
# AAACATTGAGCTAC-1                          0.04                        0.02
# AAACATTGATCAGC-1                          0.02                        0.01
# AAACCGTGCTTCCG-1                          0.45                        0.00
# AAACCGTGTATGCG-1                          0.04                        0.00
# ...                                        ...                         ...
# TTTCGAACTCTCAT-1                          0.02                        0.00
# TTTCTACTGAGGCA-1                          0.02                        0.01
# TTTCTACTTCCTCG-1                          0.00                        0.00
# TTTGCATGAGAGGC-1                          0.00                        0.00
# TTTGCATGCCTCAC-1                          0.00                        0.00
#
#                   probability_NK
# AAACATACAACCAC-1            0.00
# AAACATTGAGCTAC-1            0.00
# AAACATTGATCAGC-1            0.02
# AAACCGTGCTTCCG-1            0.00
# AAACCGTGTATGCG-1            0.36
# ...                          ...
# TTTCGAACTCTCAT-1            0.00
# TTTCTACTGAGGCA-1            0.00
# TTTCTACTTCCTCG-1            0.00
# TTTGCATGAGAGGC-1            0.00
# TTTGCATGCCTCAC-1            0.00
#
# [2638 rows x 16 columns]

# %%
adata.obs['annotated_cell_type'] = adata.obs['leiden'].to_list()

# %%
sc.pl.umap(adata, color=['annotated_cell_type', 'predicted_cell_type', 'cell_type_probability'],
          frameon=False, ncols=1)
# Out:
# ... storing 'predicted_cell_type' as categorical
# ... storing 'annotated_cell_type' as categorical
