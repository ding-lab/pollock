# %%
from pathlib import Path

import anndata
import scanpy as sc
import pandas as pd
import seaborn as sns

import pollock
from pollock.models.model import predict_from_anndata, embed_from_anndata

# %% [markdown]
# Specify which module to use for cell type predictions. If you haven't trained a module yet try building one with the [pbmc module training](https://github.com/ding-lab/pollock/blob/master/examples/pbmc_model_training.ipynb) example

# %%
module_filepath = 'modules/pbmc'

# %% [markdown]
# download adata object here
#
# it is also the same anndata object create here

# %%
adata = sc.read_h5ad('data/pbmc.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# create a new anndata object where raw counts are stored in .X

# %%
prediction_adata = sc.read_10x_mtx('data/filtered_gene_bc_matrices/hg19/', var_names='gene_symbols')
prediction_adata.var_names_make_unique()
prediction_adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %% [markdown]
# predict cell types

# %%
predictions = predict_from_anndata(prediction_adata.copy(), module_filepath)
predictions
# Out:
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# 2020-11-11 13:52:08,023 normalizing counts for prediction
# 2020-11-11 13:52:08,025 filtering for genes in training set
# 2020-11-11 13:52:08,040 0 genes in training set are missing from prediction set
# 2020-11-11 13:52:09,549 starting batch 1 of 1
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# 2020-11-11 13:52:09,598 normalizing counts for prediction
# 2020-11-11 13:52:09,598 filtering for genes in training set
# 2020-11-11 13:52:09,611 0 genes in training set are missing from prediction set
#                  predicted_cell_type  cell_type_probability  probability_B  \
# AAACATACAACCAC-1               CD4 T                   0.94           0.00
# AAACATTGAGCTAC-1                   B                   0.79           0.79
# AAACATTGATCAGC-1               CD4 T                   0.79           0.01
# AAACCGTGCTTCCG-1      CD14 Monocytes                   0.44           0.01
# AAACCGTGTATGCG-1                  NK                   0.59           0.02
# ...                              ...                    ...            ...
# TTTCGAACTCTCAT-1      CD14 Monocytes                   0.70           0.00
# TTTCTACTGAGGCA-1                   B                   0.56           0.56
# TTTCTACTTCCTCG-1                   B                   0.84           0.84
# TTTGCATGAGAGGC-1                   B                   0.53           0.53
# TTTGCATGCCTCAC-1               CD4 T                   0.58           0.08
#
#                   probability_CD14 Monocytes  probability_CD4 T  \
# AAACATACAACCAC-1                        0.00               0.94
# AAACATTGAGCTAC-1                        0.01               0.09
# AAACATTGATCAGC-1                        0.02               0.79
# AAACCGTGCTTCCG-1                        0.44               0.02
# AAACCGTGTATGCG-1                        0.12               0.01
# ...                                      ...                ...
# TTTCGAACTCTCAT-1                        0.70               0.01
# TTTCTACTGAGGCA-1                        0.01               0.21
# TTTCTACTTCCTCG-1                        0.03               0.04
# TTTGCATGAGAGGC-1                        0.10               0.08
# TTTGCATGCCTCAC-1                        0.00               0.58
#
#                   probability_CD8 T  probability_Dendritic  \
# AAACATACAACCAC-1               0.06                   0.00
# AAACATTGAGCTAC-1               0.03                   0.03
# AAACATTGATCAGC-1               0.17                   0.00
# AAACCGTGCTTCCG-1               0.06                   0.00
# AAACCGTGTATGCG-1               0.14                   0.00
# ...                             ...                    ...
# TTTCGAACTCTCAT-1               0.00                   0.03
# TTTCTACTGAGGCA-1               0.08                   0.06
# TTTCTACTTCCTCG-1               0.06                   0.00
# TTTGCATGAGAGGC-1               0.21                   0.00
# TTTGCATGCCTCAC-1               0.33                   0.00
#
#                   probability_FCGR3A Monocytes  probability_Megakaryocytes  \
# AAACATACAACCAC-1                          0.00                         0.0
# AAACATTGAGCTAC-1                          0.05                         0.0
# AAACATTGATCAGC-1                          0.01                         0.0
# AAACCGTGCTTCCG-1                          0.44                         0.0
# AAACCGTGTATGCG-1                          0.12                         0.0
# ...                                        ...                         ...
# TTTCGAACTCTCAT-1                          0.26                         0.0
# TTTCTACTGAGGCA-1                          0.03                         0.0
# TTTCTACTTCCTCG-1                          0.01                         0.0
# TTTGCATGAGAGGC-1                          0.03                         0.0
# TTTGCATGCCTCAC-1                          0.00                         0.0
#
#                   probability_NK
# AAACATACAACCAC-1            0.00
# AAACATTGAGCTAC-1            0.00
# AAACATTGATCAGC-1            0.00
# AAACCGTGCTTCCG-1            0.03
# AAACCGTGTATGCG-1            0.59
# ...                          ...
# TTTCGAACTCTCAT-1            0.00
# TTTCTACTGAGGCA-1            0.05
# TTTCTACTTCCTCG-1            0.02
# TTTGCATGAGAGGC-1            0.05
# TTTGCATGCCTCAC-1            0.01
#
# [2700 rows x 10 columns]

# %%
# merge the predictions with our pbmc anndata object
adata.obs = pd.merge(adata.obs, predictions, left_index=True, right_index=True)
adata.obs
# Out:
#                   n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACATACAACCAC-1      781                779        2419.0             73.0
# AAACATTGAGCTAC-1     1352               1352        4903.0            186.0
# AAACATTGATCAGC-1     1131               1129        3147.0             28.0
# AAACCGTGCTTCCG-1      960                960        2639.0             46.0
# AAACCGTGTATGCG-1      522                521         980.0             12.0
# ...                   ...                ...           ...              ...
# TTTCGAACTCTCAT-1     1155               1153        3459.0             73.0
# TTTCTACTGAGGCA-1     1227               1224        3443.0             32.0
# TTTCTACTTCCTCG-1      622                622        1684.0             37.0
# TTTGCATGAGAGGC-1      454                452        1022.0             21.0
# TTTGCATGCCTCAC-1      724                723        1984.0             16.0
#
#                   pct_counts_mt          leiden predicted_cell_type  \
# AAACATACAACCAC-1       3.017776           CD4 T               CD4 T
# AAACATTGAGCTAC-1       3.793596               B                   B
# AAACATTGATCAGC-1       0.889736           CD4 T               CD4 T
# AAACCGTGCTTCCG-1       1.743085  CD14 Monocytes      CD14 Monocytes
# AAACCGTGTATGCG-1       1.224490              NK                  NK
# ...                         ...             ...                 ...
# TTTCGAACTCTCAT-1       2.110436  CD14 Monocytes      CD14 Monocytes
# TTTCTACTGAGGCA-1       0.929422               B                   B
# TTTCTACTTCCTCG-1       2.197150               B                   B
# TTTGCATGAGAGGC-1       2.054795               B                   B
# TTTGCATGCCTCAC-1       0.806452           CD4 T               CD4 T
#
#                   cell_type_probability  probability_B  \
# AAACATACAACCAC-1                   0.94           0.00
# AAACATTGAGCTAC-1                   0.79           0.79
# AAACATTGATCAGC-1                   0.79           0.01
# AAACCGTGCTTCCG-1                   0.44           0.01
# AAACCGTGTATGCG-1                   0.59           0.02
# ...                                 ...            ...
# TTTCGAACTCTCAT-1                   0.70           0.00
# TTTCTACTGAGGCA-1                   0.56           0.56
# TTTCTACTTCCTCG-1                   0.84           0.84
# TTTGCATGAGAGGC-1                   0.53           0.53
# TTTGCATGCCTCAC-1                   0.58           0.08
#
#                   probability_CD14 Monocytes  probability_CD4 T  \
# AAACATACAACCAC-1                        0.00               0.94
# AAACATTGAGCTAC-1                        0.01               0.09
# AAACATTGATCAGC-1                        0.02               0.79
# AAACCGTGCTTCCG-1                        0.44               0.02
# AAACCGTGTATGCG-1                        0.12               0.01
# ...                                      ...                ...
# TTTCGAACTCTCAT-1                        0.70               0.01
# TTTCTACTGAGGCA-1                        0.01               0.21
# TTTCTACTTCCTCG-1                        0.03               0.04
# TTTGCATGAGAGGC-1                        0.10               0.08
# TTTGCATGCCTCAC-1                        0.00               0.58
#
#                   probability_CD8 T  probability_Dendritic  \
# AAACATACAACCAC-1               0.06                   0.00
# AAACATTGAGCTAC-1               0.03                   0.03
# AAACATTGATCAGC-1               0.17                   0.00
# AAACCGTGCTTCCG-1               0.06                   0.00
# AAACCGTGTATGCG-1               0.14                   0.00
# ...                             ...                    ...
# TTTCGAACTCTCAT-1               0.00                   0.03
# TTTCTACTGAGGCA-1               0.08                   0.06
# TTTCTACTTCCTCG-1               0.06                   0.00
# TTTGCATGAGAGGC-1               0.21                   0.00
# TTTGCATGCCTCAC-1               0.33                   0.00
#
#                   probability_FCGR3A Monocytes  probability_Megakaryocytes  \
# AAACATACAACCAC-1                          0.00                         0.0
# AAACATTGAGCTAC-1                          0.05                         0.0
# AAACATTGATCAGC-1                          0.01                         0.0
# AAACCGTGCTTCCG-1                          0.44                         0.0
# AAACCGTGTATGCG-1                          0.12                         0.0
# ...                                        ...                         ...
# TTTCGAACTCTCAT-1                          0.26                         0.0
# TTTCTACTGAGGCA-1                          0.03                         0.0
# TTTCTACTTCCTCG-1                          0.01                         0.0
# TTTGCATGAGAGGC-1                          0.03                         0.0
# TTTGCATGCCTCAC-1                          0.00                         0.0
#
#                   probability_NK
# AAACATACAACCAC-1            0.00
# AAACATTGAGCTAC-1            0.00
# AAACATTGATCAGC-1            0.00
# AAACCGTGCTTCCG-1            0.03
# AAACCGTGTATGCG-1            0.59
# ...                          ...
# TTTCGAACTCTCAT-1            0.00
# TTTCTACTGAGGCA-1            0.05
# TTTCTACTTCCTCG-1            0.02
# TTTGCATGAGAGGC-1            0.05
# TTTGCATGCCTCAC-1            0.01
#
# [2638 rows x 16 columns]

# %%
adata.obs['annotated_cell_type'] = adata.obs['leiden'].to_list()

# %%
sc.pl.umap(adata, color=['annotated_cell_type', 'predicted_cell_type', 'cell_type_probability'],
          frameon=False, ncols=1)
# Out:
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'predicted_cell_type' as categorical
# ... storing 'annotated_cell_type' as categorical

# %% [markdown]
# ## visualization of cell embeddings

# %% [markdown]
# with pollock we can also visualize the cell embeddings created by the BVAE

# %%
cell_embeddings = embed_from_anndata(prediction_adata.copy(), module_filepath)
cell_embeddings
# Out:
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# 2020-11-11 13:55:31,705 normalizing counts for prediction
# 2020-11-11 13:55:31,706 filtering for genes in training set
# 2020-11-11 13:55:31,718 0 genes in training set are missing from prediction set
# 2020-11-11 13:55:32,446 starting batch 1 of 1
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# 2020-11-11 13:55:32,492 normalizing counts for prediction
# 2020-11-11 13:55:32,493 filtering for genes in training set
# 2020-11-11 13:55:32,503 0 genes in training set are missing from prediction set
#                   CELL_EMBEDDING_1  CELL_EMBEDDING_2  CELL_EMBEDDING_3  \
# AAACATACAACCAC-1         -2.993413         -1.127381         -2.385087
# AAACATTGAGCTAC-1         -6.387303         10.727186          1.870051
# AAACATTGATCAGC-1         -2.986861         -1.307431         -3.392030
# AAACCGTGCTTCCG-1         -2.324390         -1.069249         -2.862015
# AAACCGTGTATGCG-1         -0.969010         -0.528899         -2.437463
# ...                            ...               ...               ...
# TTTCGAACTCTCAT-1         -2.447875         -1.932949         -4.410213
# TTTCTACTGAGGCA-1         -4.337831         -2.059378         -3.630879
# TTTCTACTTCCTCG-1         -1.829705         -1.165770          0.245678
# TTTGCATGAGAGGC-1         -0.826325         -0.420218         -0.782476
# TTTGCATGCCTCAC-1         -2.265770         -1.513220         -2.225545
#
#                   CELL_EMBEDDING_4  CELL_EMBEDDING_5  CELL_EMBEDDING_6  \
# AAACATACAACCAC-1          0.149518          1.614461         -3.019922
# AAACATTGAGCTAC-1         -2.076640          1.661025         -5.656908
# AAACATTGATCAGC-1          0.064502          1.816877         -4.717029
# AAACCGTGCTTCCG-1          0.734660          1.639713         -0.779908
# AAACCGTGTATGCG-1         -0.106089          1.277819         -0.721616
# ...                            ...               ...               ...
# TTTCGAACTCTCAT-1          0.718213          1.428382         -1.280497
# TTTCTACTGAGGCA-1          0.723641          4.920625         -3.985114
# TTTCTACTTCCTCG-1          0.582637          1.411597         -1.852302
# TTTGCATGAGAGGC-1          0.263778          0.557846         -0.047672
# TTTGCATGCCTCAC-1          0.084669          1.311085         -2.708218
#
#                   CELL_EMBEDDING_7  CELL_EMBEDDING_8  CELL_EMBEDDING_9  \
# AAACATACAACCAC-1         -4.039631          3.536440         -2.433611
# AAACATTGAGCTAC-1        -15.652678         18.007107         -1.315315
# AAACATTGATCAGC-1         -5.638947          5.558148         -3.829762
# AAACCGTGCTTCCG-1         -5.283562          5.260331         -1.263472
# AAACCGTGTATGCG-1         -1.547225          0.668738         -1.170294
# ...                            ...               ...               ...
# TTTCGAACTCTCAT-1         -5.992040          6.703271         -1.575921
# TTTCTACTGAGGCA-1         -8.405409          4.947689         -5.212725
# TTTCTACTTCCTCG-1         -2.241416          2.208624         -0.834246
# TTTGCATGAGAGGC-1         -1.827323          1.260576         -0.638670
# TTTGCATGCCTCAC-1         -4.191811          3.155246         -1.747865
#
#                   CELL_EMBEDDING_10  CELL_EMBEDDING_11  CELL_EMBEDDING_12  \
# AAACATACAACCAC-1          -0.742072           7.792282           2.446209
# AAACATTGAGCTAC-1          -0.380462          23.325684          12.875451
# AAACATTGATCAGC-1          -0.234113          11.469515           3.671299
# AAACCGTGCTTCCG-1           1.006554           8.071692           4.363327
# AAACCGTGTATGCG-1           0.929204           3.966984           1.007490
# ...                             ...                ...                ...
# TTTCGAACTCTCAT-1           0.032998          10.188437           5.937206
# TTTCTACTGAGGCA-1          -0.862455          14.202090           5.107028
# TTTCTACTTCCTCG-1          -1.923069           4.342216           2.446492
# TTTGCATGAGAGGC-1          -0.549755           2.503616           1.040287
# TTTGCATGCCTCAC-1          -0.841559           6.788596           2.407607
#
#                   CELL_EMBEDDING_13  CELL_EMBEDDING_14  CELL_EMBEDDING_15  \
# AAACATACAACCAC-1          -2.238359          -2.112278           0.636107
# AAACATTGAGCTAC-1          -2.692018         -13.977031           8.728050
# AAACATTGATCAGC-1          -2.864303          -3.649732           0.276563
# AAACCGTGCTTCCG-1          -2.449419          -0.208883          -0.957759
# AAACCGTGTATGCG-1          -0.781708          -1.178509          -1.026811
# ...                             ...                ...                ...
# TTTCGAACTCTCAT-1          -4.996279          -1.331706          -1.507487
# TTTCTACTGAGGCA-1          -3.475716          -2.936778           0.068848
# TTTCTACTTCCTCG-1          -1.977263          -2.308341          -1.161409
# TTTGCATGAGAGGC-1          -1.098822          -0.978404           0.350866
# TTTGCATGCCTCAC-1          -2.007620          -2.127193           0.627477
#
#                   CELL_EMBEDDING_16  CELL_EMBEDDING_17  CELL_EMBEDDING_18  \
# AAACATACAACCAC-1           1.735495          -2.693691           0.842397
# AAACATTGAGCTAC-1          -1.256064          -5.195498          -9.596653
# AAACATTGATCAGC-1           3.218193          -4.600825           1.449959
# AAACCGTGCTTCCG-1           1.878945          -4.778939          -0.593856
# AAACCGTGTATGCG-1           0.530609          -1.419663           0.722622
# ...                             ...                ...                ...
# TTTCGAACTCTCAT-1           3.773921          -6.452791           0.697092
# TTTCTACTGAGGCA-1           4.505252          -5.743211          -1.379370
# TTTCTACTTCCTCG-1           1.965177          -1.532500           0.167320
# TTTGCATGAGAGGC-1           1.125976          -1.758325          -0.022049
# TTTGCATGCCTCAC-1           1.306063          -2.502409           0.535367
#
#                   CELL_EMBEDDING_19  CELL_EMBEDDING_20
# AAACATACAACCAC-1          -2.877926           0.244462
# AAACATTGAGCTAC-1          -5.275183          -0.661913
# AAACATTGATCAGC-1          -2.924971           1.572568
# AAACCGTGCTTCCG-1          -1.659774           0.891991
# AAACCGTGTATGCG-1          -0.534044           0.867263
# ...                             ...                ...
# TTTCGAACTCTCAT-1          -0.592474           0.683919
# TTTCTACTGAGGCA-1          -3.389323           1.106679
# TTTCTACTTCCTCG-1          -2.381935           0.271346
# TTTGCATGAGAGGC-1          -1.226417           0.646170
# TTTGCATGCCTCAC-1          -2.010840           0.163074
#
# [2700 rows x 20 columns]

# %%
adata.obsm['cell_embeddings'] = cell_embeddings.loc[adata.obs.index].values

# %% [markdown]
# replace pca generated nearest neighbor and umap with cell embedding generated one

# %%
adata.obsm['X_umap'] = umap.UMAP().fit_transform(adata.obsm['cell_embeddings'])

# %%
sc.pl.umap(adata, color=['annotated_cell_type', 'predicted_cell_type', 'cell_type_probability'],
          frameon=False, ncols=1)
# Out:
# /home/estorrs/miniconda3/envs/pollock_dev/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
